# %%
import pyrpl

# %%
HOSTNAME = '172.16.20.41'

# %%
p = pyrpl.Pyrpl(hostname=HOSTNAME) #, config='18-nov-config')
# Out:
# INFO:pyrpl:Please select or create a configuration file in the file selector window!
# THIS IS TIMO!!!!
# INFO:pyrpl:All your PyRPL settings will be saved to the config file
#     /home/EUD002691/pyrpl_user_dir/config/18-nov-config.yml
# If you would like to restart PyRPL with these settings, type "pyrpl.exe 18-nov-config" in a windows terminal or
#     from pyrpl import Pyrpl
#     p = Pyrpl('18-nov-config')
# in a python terminal.
# INFO:pyrpl.redpitaya:Successfully connected to Redpitaya with hostname 172.16.20.41.
# WARNING:pyrpl.modules:Register pause_gains of module pid0 has value 7, which does not correspond to selected option 0. Setting to 'off'.
# QLayout::addChildLayout: layout "" already has a parent

# %%
import sys
sys.version
# Out:
# '3.8.20 (default, Oct  2 2024, 16:34:12) \n[Clang 18.1.8 ]'

# %%
s = p.rp.scope
s.input1 = 'iq1'

# %%
s.input2= 'in1'

# %%
iq0 = p.rp.iq0
iq0.output_signal = 'output_direct'

# %%
s.input1 = 'iq0'
s.voltage_in1
# Out:
# -0.0098876953125
# WARNING:pyrpl.modules:Requested gain for iq0._g1 is outside the bounds allowed by the hardware. Desired gain of 8.0e+02 is capped to 5.1e+02.

# %%
iq1 = p.rp.iq1
iq1.output_signal = 'quadrature'

# %%
s.input2 = 'iq1'
s.voltage_in2
# Out:
# 0.0

# %%
print(s.voltage_in1)
print(s.voltage_in2)

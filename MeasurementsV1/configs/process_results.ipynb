# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
folderpath = "drift_data/run_2025-12-03_17-17-43" 
print(folderpath + "/0/t.npy")
t =  np.load(folderpath + "/0/t.npy")

N = 3
""" 
for i in range(N): 
    data = np.load(f"{folderpath}/{i}/res.npy")
print(data)
"""
# Out:
# drift_data/run_2025-12-03_17-17-43/0/t.npy
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 3
#       1 folderpath = "drift_data/run_2025-12-03_17-17-43"
#       2 print(folderpath + "/0/t.npy")
# ----> 3 t =  np.load(folderpath + "/0/t.npy")
#       5 N = 3
#       6 """
#       7 for i in range(N):
#       8     data = np.load(f"{folderpath}/{i}/res.npy")
#       9 print(data)
#      10 """
#
# File ~/Documents/pyrpl/.venv/lib/python3.8/site-packages/numpy/lib/npyio.py:405, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     403     own_fid = False
#     404 else:
# --> 405     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     406     own_fid = True
#     408 # Code to distinguish from NumPy binary files and pickles.
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sdf = os.path(folderpath)
#       2 sdf
#
# TypeError: 'module' object is not callable

# %%
import os
print("cwd:", os.getcwd())
print("repr(folderpath):", repr(folderpath))
print("exists:", os.path.exists(folderpath))
print("drift_data exists:", os.path.exists("drift_data"))
if os.path.exists("drift_data"):
    print("drift_data contents:", sorted(os.listdir("drift_data")))
# Out:
# cwd: /home/EUD002691/Documents/pyrpl/MeasurementsV1/configs
# repr(folderpath): 'drift_data/run_2025-12-03_17-17-43'
# exists: False
# drift_data exists: False

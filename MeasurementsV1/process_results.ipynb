# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
folderpath = "drift_data/run_2025-12-03_17-17-43" 
print(folderpath + "/0/t.npy")
t =  np.load(folderpath + "/0/t.npy")
N = 3

for i in range(N): 
    data = np.load(f"{folderpath}/{i}/res.npy")
    print(data)
# Out:
# drift_data/run_2025-12-03_17-17-43/0/t.npy
# [[-0.01391602 -0.01171875 -0.01574707 ... -0.11462402 -0.11413574
#   -0.10668945]
#  [-0.09289551 -0.09277344 -0.09301758 ... -0.09838867 -0.09838867
#   -0.09838867]]
# [[-0.01013184 -0.01074219 -0.00805664 ... -0.03186035 -0.03259277
#   -0.03479004]
#  [-0.16699219 -0.16699219 -0.16699219 ... -0.17016602 -0.17016602
#   -0.17016602]]
# [[ 0.00524902  0.0065918   0.00402832 ...  0.08544922  0.08361816
#    0.08666992]
#  [-0.16516113 -0.16516113 -0.1652832  ... -0.16320801 -0.16320801
#   -0.16320801]]
